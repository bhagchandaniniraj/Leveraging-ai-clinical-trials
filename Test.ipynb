# %%
# Install required packages
# !pip install pandas requests tqdm psutil

import pandas as pd
import requests
from tqdm import tqdm
import os
import logging
import psutil
import sys
import json
import threading
import concurrent.futures

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# File to save the API data (JSON format)
DATA_FILE = "clinical_drug_trials_all_records.json"
# Lock for thread-safe JSON writing
json_lock = threading.Lock()

# Display the JSON file download location
json_path = os.path.abspath(DATA_FILE)
logging.info(f"JSON file will be downloaded/saved at: {json_path}")

# Function to check available RAM
def check_available_ram():
    memory = psutil.virtual_memory()
    available_ram = memory.available / (1024 ** 3)  # Convert to GB
    logging.info(f"Available RAM: {available_ram:.2f} GB")
    return available_ram

# Step 1: Fetch Total Number of Clinical Drug Trials with Progress Bar
def fetch_page_for_count(page_token=None):
    base_url = "https://clinicaltrials.gov/api/v2/studies"
    params = {
        "query.intr": "Drug",
        "filter.advanced": "AREA[StudyType]INTERVENTIONAL",
        "pageSize": 100,
        "pageToken": page_token
    }
    try:
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            studies = data.get('studies', [])
            next_page_token = data.get('nextPageToken')
            return len(studies), next_page_token
        else:
            logging.error(f"Error fetching page for count: {response.status_code} - {response.text}")
            return 0, None
    except Exception as e:
        logging.error(f"Exception during page fetch for count: {e}")
        return 0, None

def get_total_study_count(max_workers=1):
    try:
        # First, try the /stats/size endpoint with filters
        base_url = "https://clinicaltrials.gov/api/v2/stats/size"
        params = {
            "query.intr": "Drug",
            "filter.advanced": "AREA[StudyType]INTERVENTIONAL"
        }
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            total_studies = data.get('studies', 0)
            if total_studies > 0:
                logging.info(f"Total clinical drug trials from /stats/size: {total_studies}")
                return total_studies

        # If /stats/size fails or returns 0, estimate by fetching pages in parallel with a progress bar
        logging.warning("Failed to get total study count from /stats/size. Estimating via parallel fetch...")
        total_count = 0
        next_page_token = None
        page_tokens = [None]
        max_pages_to_estimate = 10  # Limit estimation to 10 pages to avoid infinite loop

        with tqdm(total=max_pages_to_estimate * 100, desc="Estimating total studies", unit="studies") as pbar:
            pages_fetched = 0
            while page_tokens and pages_fetched < max_pages_to_estimate:
                with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
                    future_to_token = {executor.submit(fetch_page_for_count, token): token for token in page_tokens}
                    page_tokens = []

                    for future in concurrent.futures.as_completed(future_to_token):
                        page_count, next_token = future.result()
                        total_count += page_count
                        pbar.update(page_count)
                        if next_token:
                            page_tokens.append(next_token)
                pages_fetched += 1

        # Estimate total based on pages fetched
        if total_count > 0:
            pages_fetched = total_count // 100
            estimated_total = total_count * (max_pages_to_estimate / pages_fetched) if pages_fetched > 0 else total_count * 10
            logging.info(f"Estimated total clinical drug trials: {int(estimated_total)}")
            return int(estimated_total)
        else:
            logging.warning("Could not estimate total study count. Using default large number for progress.")
            return 100000  # Default large number for progress bar
    except Exception as e:
        logging.error(f"Exception occurred while fetching total study count: {e}")
        return 100000  # Default large number for progress bar

# Step 1.1: Check if JSON File Exists and Estimate Record Count
def check_existing_json():
    if not os.path.exists(DATA_FILE):
        return 0  # File doesn't exist, need to download

    try:
        total_records = 0
        file_size = os.path.getsize(DATA_FILE) // (1024 ** 2)  # File size in MB
        with open(DATA_FILE, 'r', encoding='utf-8') as f:
            # Read the file as a JSON array
            f.seek(0)
            if f.read(1) != '[':  # Check if file starts with a JSON array
                return 0  # Invalid JSON format, assume empty
            f.seek(1)  # Move to the start of the first record
            with tqdm(total=file_size, desc="Counting JSON records", unit="MB") as pbar:
                while True:
                    try:
                        # Read one JSON object at a time
                        obj = json.loads(f.read(1) + f.read(f.read().find('}') + 1))
                        total_records += 1
                        # Update progress bar based on current position in file
                        current_pos = f.tell() // (1024 ** 2)  # Current position in MB
                        pbar.n = min(current_pos, file_size)  # Update progress
                        pbar.refresh()
                        # Skip comma and whitespace
                        while f.read(1) in [',', ' ', '\n']:
                            pass
                        f.seek(f.tell() - 1)
                    except json.JSONDecodeError:
                        break  # End of array or invalid JSON
        logging.info(f"Existing JSON file contains {total_records} records.")
        return total_records
    except Exception as e:
        logging.error(f"Error reading existing JSON file: {e}. Will re-download data.")
        return 0

# Step 1.2: Fetch a Single Page of Data
def fetch_page(page_token=None):
    base_url = "https://clinicaltrials.gov/api/v2/studies"
    params = {
        "query.intr": "Drug",
        "filter.advanced": "AREA[StudyType]INTERVENTIONAL",
        "pageSize": 100,
        "pageToken": page_token
    }
    try:
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            studies = data.get('studies', [])
            next_page_token = data.get('nextPageToken')
            return studies, next_page_token
        else:
            logging.error(f"Error fetching page with token {page_token}: {response.status_code} - {response.text}")
            return None, None
    except Exception as e:
        logging.error(f"Exception occurred during API request for page with token {page_token}: {e}")
        return None, None

# Step 1.3: Save Fetched Studies to JSON (Thread-Safe)
def save_to_json(studies, first_chunk=True):
    if not studies:
        return

    with json_lock:
        mode = 'a' if not first_chunk else 'w'
        with open(DATA_FILE, mode, encoding='utf-8') as f:
            if first_chunk:
                # Start the JSON array
                f.write('[')
            else:
                # Add a comma to separate from previous entries
                f.write(',')
            # Write each study as a JSON object
            for i, study in enumerate(studies):
                json.dump(study, f, ensure_ascii=False)
                if i < len(studies) - 1:
                    f.write(',')
            # If this is the last chunk, close the array (handled in fetch_clinical_trials)

# Step 1.4: Fetch All Clinical Drug Trials with Parallel Downloads and Save as JSON
def fetch_clinical_trials(max_workers=1):
    check_available_ram()
    total_studies = get_total_study_count(max_workers=max_workers)
    if total_studies == 0:
        logging.warning("API returned 0 studies. Attempting to fetch at least one page...")
        studies, next_page_token = fetch_page()
        if studies:
            total_studies = max(len(studies) * 100, 100000)  # Rough estimate
        else:
            logging.error("No studies fetched. Using default large number for progress.")
            total_studies = 100000

    existing_records = check_existing_json()
    if existing_records >= total_studies > 0:
        logging.info("JSON file already contains all records. Skipping download.")
        # Ensure the JSON file is properly closed with a closing bracket
        with open(DATA_FILE, 'rb+') as f:
            f.seek(-1, os.SEEK_END)
            last_char = f.read(1).decode('utf-8')
            if last_char != ']':
                f.seek(-1, os.SEEK_END)
                f.write(b']')
        return

    if os.path.exists(DATA_FILE):
        os.remove(DATA_FILE)

    studies_fetched = 0
    next_page_token = None
    page_tokens = [None]
    first_chunk = True

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        with tqdm(total=total_studies, desc="Fetching clinical drug trials", unit="studies") as pbar:
            while page_tokens:
                check_available_ram()
                if psutil.virtual_memory().available / (1024 ** 3) < 0.5:  # Less than 0.5 GB available
                    logging.warning("Low RAM available. Pausing fetch to free memory...")
                    sys.stdout.flush()
                    break
                future_to_token = {executor.submit(fetch_page, token): token for token in page_tokens}
                page_tokens = []

                for future in concurrent.futures.as_completed(future_to_token):
                    studies, next_token = future.result()
                    if studies:
                        save_to_json(studies, first_chunk=first_chunk)
                        first_chunk = False
                        studies_fetched += len(studies)
                        pbar.update(len(studies))
                    if next_token:
                        page_tokens.append(next_token)

    # Close the JSON array
    with open(DATA_FILE, 'a', encoding='utf-8') as f:
        f.write(']')

    logging.info(f"Fetched {studies_fetched} clinical drug trials and saved to {json_path}.")

# Main Workflow
def main():
    # Fetch all clinical drug trials and save as JSON
    fetch_clinical_trials()
    logging.info("Data fetching complete. You can now access the data in the JSON file for your research.")

if __name__ == "__main__":
    main()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\program files\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: requests in c:\program files\python312\lib\site-packages (2.32.3)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\roaming\python\python312\site-packages (4.67.1)
# Requirement already satisfied: psutil in c:\program files\python312\lib\site-packages (6.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\program files\python312\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\program files\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\program files\python312\lib\site-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\program files\python312\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python312\lib\site-packages (from requests) (2024.7.4)
# Requirement already satisfied: colorama in c:\program files\python312\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\program files\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# 2025-06-05 23:59:26,587 - INFO - JSON file will be downloaded/saved at: d:\IIT Patna\Leveraging-ai-clinical-trials\clinical_drug_trials_all_records.json
# 2025-06-05 23:59:26,594 - INFO - Available RAM: 1.79 GB
# 2025-06-05 23:59:27,013 - WARNING - Failed to get total study count from /stats/size. Estimating via parallel fetch...
# Estimating total studies: 100%|██████████| 1000/1000 [00:14<00:00, 70.30studies/s]
# 2025-06-05 23:59:41,266 - INFO - Estimated total clinical drug trials: 1000
# Fetching clinical drug trials:   0%|          | 0/1000 [00:00<?, ?studies/s]2025-06-05 23:59:41,266 - INFO - Available RAM: 1.92 GB
# Fetching clinical drug trials:  10%|█         | 100/1000 [00:01<00:16, 55.03studies/s]2025-06-05 23:59:43,083 - INFO - Available RAM: 1.88 GB
# Fetching clinical drug trials:  20%|██        | 200/1000 [00:03<00:14, 54.81studies/s]2025-06-05 23:59:44,920 - INFO - Available RAM: 1.86 GB
# Fetching clinical drug trials:  30%|███       | 300/1000 [00:04<00:11, 63.42studies/s]2025-06-05 23:59:46,195 - INFO - Available RAM: 1.87 GB
# Fetching clinical drug trials:  40%|████      | 400/1000 [00:06<00:09, 63.60studies/s]2025-06-05 23:59:47,760 - INFO - Available RAM: 1.87 GB
# Fetching clinical drug trials:  50%|█████     | 500/1000 [00:07<00:07, 66.77studies/s]2025-06-05 23:59:49,142 - INFO - Available RAM: 1.83 GB
# Fetching clinical drug trials:  60%|██████    | 600/1000 [00:09<00:06, 65.27studies/s]2025-06-05 23:59:50,725 - INFO - Available RAM: 1.87 GB
# Fetching clinical drug trials:  70%|███████   | 700/1000 [00:11<00:04, 64.36studies/s]2025-06-05 23:59:52,323 - INFO - Available RAM: 1.88 GB
# Fetching clinical drug trials:  80%|████████  | 800/1000 [00:13<00:03, 58.41studies/s]2025-06-05 23:59:54,374 - INFO - Available RAM: 1.84 GB
# Fetching clinical drug trials:  90%|█████████ | 900/1000 [00:14<00:01, 59.58studies/s]2025-06-05 23:59:55,995 - INFO - Available RAM: 1.83 GB
# Fetching clinical drug trials: 100%|██████████| 1000/1000 [00:16<00:00, 61.19studies/s]2025-06-05 23:59:57,529 - INFO - Available RAM: 1.84 GB
# Fetching clinical drug trials: 1100studies [00:17, 60.77studies/s]                     2025-06-05 23:59:59,202 - INFO - Available RAM: 1.84 GB
# Fetching clinical drug trials: 1200studies [00:18, 70.46studies/s]2025-06-06 00:00:00,087 - INFO - Available RAM: 1.83 GB
# Fetching clinical drug trials: 1300studies [00:20, 68.73studies/s]2025-06-06 00:00:01,628 - INFO - Available RAM: 1.79 GB
# Fetching clinical drug trials: 1400studies [00:22, 65.10studies/s]2025-06-06 00:00:03,347 - INFO - Available RAM: 1.82 GB
# Fetching clinical drug trials: 1500studies [00:22, 74.40studies/s]2025-06-06 00:00:04,247 - INFO - Available RAM: 1.81 GB
# Fetching clinical drug trials: 1600studies [00:24, 68.40studies/s]2025-06-06 00:00:05,982 - INFO - Available RAM: 1.80 GB
# Fetching clinical drug trials: 1700studies [00:25, 71.58studies/s]2025-06-06 00:00:07,228 - INFO - Available RAM: 1.81 GB
# Fetching clinical drug trials: 1800studies [00:27, 72.07studies/s]2025-06-06 00:00:08,593 - INFO - Available RAM: 1.82 GB
# Fetching clinical drug trials: 1900studies [00:28, 71.64studies/s]2025-06-06 00:00:10,025 - INFO - Available RAM: 1.83 GB
# Fetching clinical drug trials: 2000studies [00:29, 75.92studies/s]2025-06-06 00:00:11,145 - INFO - Available RAM: 1.81 GB
# Fetching clinical drug trials: 2100studies [00:31, 68.15studies/s]2025-06-06 00:00:12,973 - INFO - Available RAM: 1.82 GB
# Fetching clinical drug trials: 2200studies [00:33, 64.35studies/s]2025-06-06 00:00:14,722 - INFO - Available RAM: 1.83 GB
# Fetching clinical drug trials: 2300studies [00:35, 61.57studies/s]2025-06-06 00:00:16,504 - INFO - Available RAM: 1.82 GB
# Fetching clinical drug trials: 2400studies [00:36, 69.36studies/s]2025-06-06 00:00:17,520 - INFO - Available RAM: 1.82 GB
# Fetching clinical drug trials: 2500studies [00:37, 66.40studies/s]2025-06-06 00:00:19,234 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 2600studies [00:40, 55.95studies/s]2025-06-06 00:00:21,622 - INFO - Available RAM: 1.20 GB
# Fetching clinical drug trials: 2700studies [00:42, 54.28studies/s]2025-06-06 00:00:23,606 - INFO - Available RAM: 1.27 GB
# Fetching clinical drug trials: 2800studies [00:44, 52.18studies/s]2025-06-06 00:00:25,680 - INFO - Available RAM: 1.31 GB
# Fetching clinical drug trials: 2900studies [00:45, 55.18studies/s]2025-06-06 00:00:27,249 - INFO - Available RAM: 1.40 GB
# Fetching clinical drug trials: 3000studies [00:46, 66.79studies/s]2025-06-06 00:00:28,014 - INFO - Available RAM: 1.40 GB
# Fetching clinical drug trials: 3100studies [00:47, 73.93studies/s]2025-06-06 00:00:29,027 - INFO - Available RAM: 1.40 GB
# Fetching clinical drug trials: 3200studies [00:49, 69.61studies/s]2025-06-06 00:00:30,659 - INFO - Available RAM: 1.47 GB
# Fetching clinical drug trials: 3300studies [00:50, 72.45studies/s]2025-06-06 00:00:31,908 - INFO - Available RAM: 1.47 GB
# Fetching clinical drug trials: 3400studies [00:51, 80.90studies/s]2025-06-06 00:00:32,807 - INFO - Available RAM: 1.48 GB
# Fetching clinical drug trials: 3500studies [00:53, 70.44studies/s]2025-06-06 00:00:34,665 - INFO - Available RAM: 1.48 GB
# Fetching clinical drug trials: 3600studies [00:55, 64.59studies/s]2025-06-06 00:00:36,504 - INFO - Available RAM: 1.51 GB
# Fetching clinical drug trials: 3700studies [00:57, 61.21studies/s]2025-06-06 00:00:38,340 - INFO - Available RAM: 1.60 GB
# Fetching clinical drug trials: 3800studies [00:58, 61.05studies/s]2025-06-06 00:00:40,003 - INFO - Available RAM: 1.64 GB
# Fetching clinical drug trials: 3900studies [01:00, 60.38studies/s]2025-06-06 00:00:41,700 - INFO - Available RAM: 1.65 GB
# Fetching clinical drug trials: 4000studies [01:02, 59.39studies/s]2025-06-06 00:00:43,435 - INFO - Available RAM: 1.64 GB
# Fetching clinical drug trials: 4100studies [01:02, 70.25studies/s]2025-06-06 00:00:44,248 - INFO - Available RAM: 1.64 GB
# Fetching clinical drug trials: 4200studies [01:04, 73.46studies/s]2025-06-06 00:00:45,464 - INFO - Available RAM: 1.62 GB
# Fetching clinical drug trials: 4300studies [01:06, 65.05studies/s]2025-06-06 00:00:47,429 - INFO - Available RAM: 1.60 GB
# Fetching clinical drug trials: 4400studies [01:07, 63.87studies/s]2025-06-06 00:00:49,044 - INFO - Available RAM: 1.54 GB
# Fetching clinical drug trials: 4500studies [01:09, 62.90studies/s]2025-06-06 00:00:50,693 - INFO - Available RAM: 1.50 GB
# Fetching clinical drug trials: 4600studies [01:10, 72.81studies/s]2025-06-06 00:00:51,559 - INFO - Available RAM: 1.50 GB
# Fetching clinical drug trials: 4700studies [01:12, 64.48studies/s]2025-06-06 00:00:53,524 - INFO - Available RAM: 1.49 GB
# Fetching clinical drug trials: 4800studies [01:13, 63.48studies/s]2025-06-06 00:00:55,156 - INFO - Available RAM: 1.49 GB
# Fetching clinical drug trials: 4900studies [01:15, 61.24studies/s]2025-06-06 00:00:56,939 - INFO - Available RAM: 1.48 GB
# Fetching clinical drug trials: 5000studies [01:16, 68.86studies/s]2025-06-06 00:00:57,954 - INFO - Available RAM: 1.48 GB
# Fetching clinical drug trials: 5100studies [01:18, 64.27studies/s]2025-06-06 00:00:59,752 - INFO - Available RAM: 1.46 GB
# Fetching clinical drug trials: 5200studies [01:20, 62.75studies/s]2025-06-06 00:01:01,435 - INFO - Available RAM: 1.46 GB
# Fetching clinical drug trials: 5300studies [01:21, 62.68studies/s]2025-06-06 00:01:03,033 - INFO - Available RAM: 1.48 GB
# Fetching clinical drug trials: 5400studies [01:22, 71.05studies/s]2025-06-06 00:01:04,008 - INFO - Available RAM: 1.49 GB
# Fetching clinical drug trials: 5500studies [01:23, 79.53studies/s]2025-06-06 00:01:04,915 - INFO - Available RAM: 1.50 GB
# Fetching clinical drug trials: 5600studies [01:25, 72.65studies/s]2025-06-06 00:01:06,563 - INFO - Available RAM: 1.49 GB
# Fetching clinical drug trials: 5700studies [01:26, 70.51studies/s]2025-06-06 00:01:08,095 - INFO - Available RAM: 1.49 GB
# Fetching clinical drug trials: 5800studies [01:27, 77.97studies/s]2025-06-06 00:01:09,045 - INFO - Available RAM: 1.49 GB
# Fetching clinical drug trials: 5900studies [01:28, 86.02studies/s]2025-06-06 00:01:09,927 - INFO - Available RAM: 1.51 GB
# Fetching clinical drug trials: 6000studies [01:29, 83.75studies/s]2025-06-06 00:01:11,195 - INFO - Available RAM: 1.52 GB
# Fetching clinical drug trials: 6100studies [01:31, 82.25studies/s]2025-06-06 00:01:12,461 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 6200studies [01:32, 76.92studies/s]2025-06-06 00:01:13,976 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 6300studies [01:34, 71.45studies/s]2025-06-06 00:01:15,590 - INFO - Available RAM: 1.54 GB
# Fetching clinical drug trials: 6400studies [01:35, 67.84studies/s]2025-06-06 00:01:17,238 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 6500studies [01:36, 77.72studies/s]2025-06-06 00:01:18,087 - INFO - Available RAM: 1.52 GB
# Fetching clinical drug trials: 6600studies [01:38, 68.02studies/s]2025-06-06 00:01:19,986 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 6700studies [01:39, 78.80studies/s]2025-06-06 00:01:20,802 - INFO - Available RAM: 1.52 GB
# Fetching clinical drug trials: 6800studies [01:41, 72.79studies/s]2025-06-06 00:01:22,417 - INFO - Available RAM: 1.52 GB
# Fetching clinical drug trials: 6900studies [01:42, 74.32studies/s]2025-06-06 00:01:23,683 - INFO - Available RAM: 1.52 GB
# Fetching clinical drug trials: 7000studies [01:44, 70.11studies/s]2025-06-06 00:01:25,298 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 7100studies [01:45, 65.85studies/s]2025-06-06 00:01:27,032 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 7200studies [01:46, 69.83studies/s]2025-06-06 00:01:28,279 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 7300studies [01:48, 64.47studies/s]2025-06-06 00:01:30,094 - INFO - Available RAM: 1.51 GB
# Fetching clinical drug trials: 7400studies [01:50, 62.75studies/s]2025-06-06 00:01:31,789 - INFO - Available RAM: 1.51 GB
# Fetching clinical drug trials: 7500studies [01:51, 71.53studies/s]2025-06-06 00:01:32,742 - INFO - Available RAM: 1.52 GB
# Fetching clinical drug trials: 7600studies [01:52, 71.76studies/s]2025-06-06 00:01:34,108 - INFO - Available RAM: 1.52 GB
# Fetching clinical drug trials: 7700studies [01:54, 68.04studies/s]2025-06-06 00:01:35,756 - INFO - Available RAM: 1.53 GB
# Fetching clinical drug trials: 7800studies [01:56, 59.94studies/s]2025-06-06 00:01:37,888 - INFO - Available RAM: 1.44 GB
# Fetching clinical drug trials: 7900studies [01:57, 64.62studies/s]2025-06-06 00:01:39,154 - INFO - Available RAM: 1.39 GB
# Fetching clinical drug trials: 8000studies [01:59, 64.60studies/s]2025-06-06 00:01:40,702 - INFO - Available RAM: 1.42 GB
# Fetching clinical drug trials: 8100studies [02:01, 59.77studies/s]2025-06-06 00:01:42,667 - INFO - Available RAM: 1.45 GB
# Fetching clinical drug trials: 8200studies [02:03, 54.18studies/s]2025-06-06 00:01:44,916 - INFO - Available RAM: 1.65 GB
# Fetching clinical drug trials: 8300studies [02:05, 56.77studies/s]2025-06-06 00:01:46,481 - INFO - Available RAM: 1.83 GB
# Fetching clinical drug trials: 8400studies [02:06, 59.43studies/s]2025-06-06 00:01:47,980 - INFO - Available RAM: 1.84 GB
# Fetching clinical drug trials: 8500studies [02:08, 61.82studies/s]2025-06-06 00:01:49,462 - INFO - Available RAM: 1.84 GB
# Fetching clinical drug trials: 8600studies [02:09, 65.49studies/s]2025-06-06 00:01:50,779 - INFO - Available RAM: 1.84 GB
# Fetching clinical drug trials: 8700studies [02:11, 63.55studies/s]2025-06-06 00:01:52,443 - INFO - Available RAM: 1.84 GB
# Fetching clinical drug trials: 8800studies [02:12, 63.22studies/s]2025-06-06 00:01:54,059 - INFO - Available RAM: 1.77 GB
# Fetching clinical drug trials: 8900studies [02:14, 62.08studies/s]2025-06-06 00:01:55,726 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 9000studies [02:16, 61.07studies/s]2025-06-06 00:01:57,439 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 9100studies [02:17, 61.24studies/s]2025-06-06 00:01:59,049 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 9200studies [02:19, 61.87studies/s]2025-06-06 00:02:00,622 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 9300studies [02:20, 70.84studies/s]2025-06-06 00:02:01,568 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 9400studies [02:22, 64.66studies/s]2025-06-06 00:02:03,417 - INFO - Available RAM: 1.77 GB
# Fetching clinical drug trials: 9500studies [02:23, 74.78studies/s]2025-06-06 00:02:04,267 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 9600studies [02:24, 78.38studies/s]2025-06-06 00:02:05,399 - INFO - Available RAM: 1.74 GB
# Fetching clinical drug trials: 9700studies [02:25, 69.07studies/s]2025-06-06 00:02:07,263 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 9800studies [02:26, 76.93studies/s]2025-06-06 00:02:08,219 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 9900studies [02:28, 78.12studies/s]2025-06-06 00:02:09,452 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 10000studies [02:29, 85.24studies/s]2025-06-06 00:02:10,360 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 10100studies [02:30, 75.08studies/s]2025-06-06 00:02:12,063 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 10200studies [02:31, 85.72studies/s]2025-06-06 00:02:12,844 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 10300studies [02:32, 80.44studies/s]2025-06-06 00:02:14,266 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 10400studies [02:34, 78.52studies/s]2025-06-06 00:02:15,610 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 10500studies [02:35, 72.18studies/s]2025-06-06 00:02:17,256 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 10600studies [02:37, 73.79studies/s]2025-06-06 00:02:18,541 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 10700studies [02:39, 67.91studies/s]2025-06-06 00:02:20,288 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 10800studies [02:40, 66.65studies/s]2025-06-06 00:02:21,852 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 10900studies [02:42, 62.70studies/s]2025-06-06 00:02:23,668 - INFO - Available RAM: 1.73 GB
# Fetching clinical drug trials: 11000studies [02:44, 59.31studies/s]2025-06-06 00:02:25,583 - INFO - Available RAM: 1.74 GB
# Fetching clinical drug trials: 11100studies [02:46, 59.15studies/s]2025-06-06 00:02:27,281 - INFO - Available RAM: 1.74 GB
# Fetching clinical drug trials: 11200studies [02:47, 59.63studies/s]2025-06-06 00:02:28,914 - INFO - Available RAM: 1.74 GB
# Fetching clinical drug trials: 11300studies [02:49, 56.87studies/s]2025-06-06 00:02:30,881 - INFO - Available RAM: 1.74 GB
# Fetching clinical drug trials: 11400studies [02:51, 57.95studies/s]2025-06-06 00:02:32,516 - INFO - Available RAM: 1.72 GB
# Fetching clinical drug trials: 11500studies [02:53, 57.22studies/s]2025-06-06 00:02:34,310 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 11600studies [02:54, 61.19studies/s]2025-06-06 00:02:35,683 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 11700studies [02:55, 66.69studies/s]2025-06-06 00:02:36,865 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 11800studies [02:56, 75.35studies/s]2025-06-06 00:02:37,790 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 11900studies [02:58, 70.74studies/s]2025-06-06 00:02:39,405 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 12000studies [02:59, 78.45studies/s]2025-06-06 00:02:40,372 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 12100studies [02:59, 86.81studies/s]2025-06-06 00:02:41,221 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 12200studies [03:00, 91.25studies/s]2025-06-06 00:02:42,204 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 12300studies [03:02, 73.71studies/s]2025-06-06 00:02:44,151 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 12400studies [03:04, 67.38studies/s]2025-06-06 00:02:45,950 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 12500studies [03:06, 63.53studies/s]2025-06-06 00:02:47,717 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 12600studies [03:07, 64.46studies/s]2025-06-06 00:02:49,215 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 12700studies [03:08, 74.33studies/s]2025-06-06 00:02:50,093 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 12800studies [03:10, 68.64studies/s]2025-06-06 00:02:51,797 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 12900studies [03:12, 65.20studies/s]2025-06-06 00:02:53,527 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 13000studies [03:14, 60.86studies/s]2025-06-06 00:02:55,409 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 13100studies [03:15, 60.98studies/s]2025-06-06 00:02:57,041 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 13200studies [03:17, 58.40studies/s]2025-06-06 00:02:58,923 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 13300studies [03:19, 59.58studies/s]2025-06-06 00:03:00,521 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 13400studies [03:20, 61.72studies/s]2025-06-06 00:03:02,018 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 13500studies [03:22, 62.58studies/s]2025-06-06 00:03:03,552 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 13600studies [03:23, 62.57studies/s]2025-06-06 00:03:05,151 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 13700studies [03:25, 63.13studies/s]2025-06-06 00:03:06,702 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 13800studies [03:27, 62.78studies/s]2025-06-06 00:03:08,315 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 13900studies [03:28, 62.33studies/s]2025-06-06 00:03:09,954 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 14000studies [03:30, 61.11studies/s]2025-06-06 00:03:11,658 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 14100studies [03:31, 61.64studies/s]2025-06-06 00:03:13,261 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 14200studies [03:32, 69.42studies/s]2025-06-06 00:03:14,271 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 14300studies [03:33, 76.42studies/s]2025-06-06 00:03:15,264 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 14400studies [03:35, 70.96studies/s]2025-06-06 00:03:16,908 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 14500studies [03:36, 73.73studies/s]2025-06-06 00:03:18,141 - INFO - Available RAM: 1.71 GB
# Fetching clinical drug trials: 14600studies [03:38, 69.99studies/s]2025-06-06 00:03:19,739 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 14700studies [03:39, 71.69studies/s]2025-06-06 00:03:21,055 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 14800studies [03:41, 72.41studies/s]2025-06-06 00:03:22,404 - INFO - Available RAM: 1.71 GB
# Fetching clinical drug trials: 14900studies [03:42, 68.06studies/s]2025-06-06 00:03:24,079 - INFO - Available RAM: 1.71 GB
# Fetching clinical drug trials: 15000studies [03:44, 66.44studies/s]2025-06-06 00:03:25,685 - INFO - Available RAM: 1.71 GB
# Fetching clinical drug trials: 15100studies [03:46, 64.56studies/s]2025-06-06 00:03:27,334 - INFO - Available RAM: 1.72 GB
# Fetching clinical drug trials: 15200studies [03:47, 63.97studies/s]2025-06-06 00:03:28,915 - INFO - Available RAM: 1.71 GB
# Fetching clinical drug trials: 15300studies [03:48, 73.31studies/s]2025-06-06 00:03:29,815 - INFO - Available RAM: 1.72 GB
# Fetching clinical drug trials: 15400studies [03:50, 67.82studies/s]2025-06-06 00:03:31,547 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 15500studies [03:51, 65.52studies/s]2025-06-06 00:03:33,197 - INFO - Available RAM: 1.76 GB
# Fetching clinical drug trials: 15600studies [03:53, 64.63studies/s]2025-06-06 00:03:34,794 - INFO - Available RAM: 1.75 GB
# Fetching clinical drug trials: 15700studies [03:54, 72.78studies/s]2025-06-06 00:03:35,776 - INFO - Available RAM: 1.73 GB
# Fetching clinical drug trials: 15800studies [03:56, 68.20studies/s]2025-06-06 00:03:37,442 - INFO - Available RAM: 1.73 GB
# Fetching clinical drug trials: 15900studies [03:57, 76.85studies/s]2025-06-06 00:03:38,377 - INFO - Available RAM: 1.73 GB
# Fetching clinical drug trials: 16000studies [03:58, 76.85studies/s]2025-06-06 00:03:39,659 - INFO - Available RAM: 1.73 GB
# Fetching clinical drug trials: 16100studies [03:59, 77.69studies/s]2025-06-06 00:03:40,922 - INFO - Available RAM: 1.72 GB
# Fetching clinical drug trials: 16200studies [04:00, 77.02studies/s]2025-06-06 00:03:42,238 - INFO - Available RAM: 1.73 GB
# Fetching clinical drug trials: 16300studies [04:02, 71.25studies/s]2025-06-06 00:03:43,886 - INFO - Available RAM: 1.73 GB
# Fetching clinical drug trials: 16400studies [04:03, 74.51studies/s]2025-06-06 00:03:45,085 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 16500studies [04:05, 70.46studies/s]2025-06-06 00:03:46,685 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 16600studies [04:07, 64.61studies/s]2025-06-06 00:03:48,533 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 16700studies [04:08, 66.96studies/s]2025-06-06 00:03:49,899 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 16800studies [04:10, 68.27studies/s]2025-06-06 00:03:51,297 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 16900studies [04:10, 76.87studies/s]2025-06-06 00:03:52,216 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 17000studies [04:12, 71.69studies/s]2025-06-06 00:03:53,830 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 17100studies [04:13, 73.76studies/s]2025-06-06 00:03:55,112 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 17200studies [04:14, 82.20studies/s]2025-06-06 00:03:55,990 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 17300studies [04:16, 71.02studies/s]2025-06-06 00:03:57,842 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 17400studies [04:18, 65.54studies/s]2025-06-06 00:03:59,650 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 17500studies [04:19, 65.04studies/s]2025-06-06 00:04:01,206 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 17600studies [04:21, 62.27studies/s]2025-06-06 00:04:02,989 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 17700studies [04:23, 62.94studies/s]2025-06-06 00:04:04,520 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 17800studies [04:24, 69.59studies/s]2025-06-06 00:04:05,603 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 17900studies [04:25, 77.49studies/s]2025-06-06 00:04:06,552 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 18000studies [04:27, 68.59studies/s]2025-06-06 00:04:08,400 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 18100studies [04:28, 67.31studies/s]2025-06-06 00:04:09,966 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 18200studies [04:30, 65.83studies/s]2025-06-06 00:04:11,547 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 18300studies [04:32, 61.59studies/s]2025-06-06 00:04:13,415 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 18400studies [04:34, 58.64studies/s]2025-06-06 00:04:15,311 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 18500studies [04:35, 57.53studies/s]2025-06-06 00:04:17,145 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 18600studies [04:37, 58.09studies/s]2025-06-06 00:04:18,809 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 18700studies [04:39, 59.36studies/s]2025-06-06 00:04:20,407 - INFO - Available RAM: 1.70 GB
# Fetching clinical drug trials: 18800studies [04:40, 60.83studies/s]2025-06-06 00:04:21,977 - INFO - Available RAM: 1.69 GB
# Fetching clinical drug trials: 18900studies [04:42, 64.50studies/s]2025-06-06 00:04:23,288 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 19000studies [04:43, 67.07studies/s]2025-06-06 00:04:24,645 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 19100studies [04:45, 64.84studies/s]2025-06-06 00:04:26,303 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 19200studies [04:46, 63.53studies/s]2025-06-06 00:04:27,951 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 19300studies [04:48, 63.23studies/s]2025-06-06 00:04:29,550 - INFO - Available RAM: 1.68 GB
# Fetching clinical drug trials: 19400studies [04:49, 66.59studies/s]2025-06-06 00:04:30,865 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 19500studies [04:51, 62.08studies/s]2025-06-06 00:04:32,730 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 19600studies [04:53, 62.60studies/s]2025-06-06 00:04:34,297 - INFO - Available RAM: 1.65 GB
# Fetching clinical drug trials: 19700studies [04:54, 62.42studies/s]2025-06-06 00:04:35,910 - INFO - Available RAM: 1.66 GB
# Fetching clinical drug trials: 19800studies [04:56, 60.00studies/s]2025-06-06 00:04:37,727 - INFO - Available RAM: 1.66 GB
# Fetching clinical drug trials: 19900studies [04:57, 68.55studies/s]2025-06-06 00:04:38,701 - INFO - Available RAM: 1.64 GB
# Fetching clinical drug trials: 20000studies [04:59, 64.80studies/s]2025-06-06 00:04:40,441 - INFO - Available RAM: 1.65 GB
# Fetching clinical drug trials: 20100studies [05:00, 69.93studies/s]2025-06-06 00:04:41,607 - INFO - Available RAM: 1.65 GB
# Fetching clinical drug trials: 20200studies [05:02, 66.20studies/s]2025-06-06 00:04:43,305 - INFO - Available RAM: 1.66 GB
# Fetching clinical drug trials: 20300studies [05:03, 60.90studies/s]2025-06-06 00:04:45,254 - INFO - Available RAM: 1.66 GB
# Fetching clinical drug trials: 20400studies [05:05, 61.20studies/s]2025-06-06 00:04:46,886 - INFO - Available RAM: 1.66 GB
# Fetching clinical drug trials: 20500studies [05:07, 62.37studies/s]2025-06-06 00:04:48,401 - INFO - Available RAM: 1.67 GB
# Fetching clinical drug trials: 20600studies [05:08, 60.17studies/s]2025-06-06 00:04:50,216 - INFO - Available RAM: 1.64 GB
# Fetching clinical drug trials: 20700studies [05:10, 58.41studies/s]2025-06-06 00:04:52,035 - INFO - Available RAM: 1.63 GB
# Fetching clinical drug trials: 20800studies [05:12, 59.21studies/s]2025-06-06 00:04:53,664 - INFO - Available RAM: 1.63 GB
# Fetching clinical drug trials: 20900studies [05:14, 55.66studies/s]2025-06-06 00:04:55,729 - INFO - Available RAM: 2.41 GB
# Fetching clinical drug trials: 21000studies [05:15, 63.80studies/s]2025-06-06 00:04:56,744 - INFO - Available RAM: 3.21 GB
# Fetching clinical drug trials: 21100studies [05:16, 71.28studies/s]2025-06-06 00:04:57,779 - INFO - Available RAM: 3.92 GB
# Fetching clinical drug trials: 21200studies [05:18, 60.95studies/s]2025-06-06 00:04:59,979 - INFO - Available RAM: 4.87 GB
# Fetching clinical drug trials: 21300studies [05:20, 62.00studies/s]2025-06-06 00:05:01,507 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 21400studies [05:21, 61.40studies/s]2025-06-06 00:05:03,173 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 21500studies [05:22, 69.94studies/s]2025-06-06 00:05:04,155 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 21600studies [05:23, 79.64studies/s]2025-06-06 00:05:04,988 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 21700studies [05:25, 71.11studies/s]2025-06-06 00:05:06,749 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 21800studies [05:27, 65.52studies/s]2025-06-06 00:05:08,568 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 21900studies [05:29, 62.39studies/s]2025-06-06 00:05:10,333 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 22000studies [05:30, 66.37studies/s]2025-06-06 00:05:11,616 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 22100studies [05:31, 75.17studies/s]2025-06-06 00:05:12,535 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 22200studies [05:32, 69.69studies/s]2025-06-06 00:05:14,214 - INFO - Available RAM: 5.35 GB
# Fetching clinical drug trials: 22300studies [05:34, 70.92studies/s]2025-06-06 00:05:15,565 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 22400studies [05:35, 70.36studies/s]2025-06-06 00:05:17,013 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 22500studies [05:37, 67.60studies/s]2025-06-06 00:05:18,627 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 22600studies [05:39, 62.84studies/s]2025-06-06 00:05:20,484 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 22700studies [05:41, 60.17studies/s]2025-06-06 00:05:22,307 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 22800studies [05:42, 66.97studies/s]2025-06-06 00:05:23,423 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 22900studies [05:43, 64.73studies/s]2025-06-06 00:05:25,072 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 23000studies [05:45, 63.02studies/s]2025-06-06 00:05:26,770 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 23100studies [05:47, 61.93studies/s]2025-06-06 00:05:28,441 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 23200studies [05:48, 70.42studies/s]2025-06-06 00:05:29,402 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 23300studies [05:49, 73.07studies/s]2025-06-06 00:05:30,651 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 23400studies [05:50, 73.34studies/s]2025-06-06 00:05:32,002 - INFO - Available RAM: 5.46 GB
# Fetching clinical drug trials: 23500studies [05:52, 67.79studies/s]2025-06-06 00:05:33,738 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 23600studies [05:54, 64.40studies/s]2025-06-06 00:05:35,472 - INFO - Available RAM: 5.90 GB
# Fetching clinical drug trials: 23700studies [05:55, 68.26studies/s]2025-06-06 00:05:36,743 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 23800studies [05:57, 65.58studies/s]2025-06-06 00:05:38,397 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 23900studies [05:58, 64.25studies/s]2025-06-06 00:05:40,043 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 24000studies [05:59, 70.41studies/s]2025-06-06 00:05:41,142 - INFO - Available RAM: 5.90 GB
# Fetching clinical drug trials: 24100studies [06:00, 75.00studies/s]2025-06-06 00:05:42,282 - INFO - Available RAM: 5.90 GB
# Fetching clinical drug trials: 24200studies [06:02, 68.86studies/s]2025-06-06 00:05:43,990 - INFO - Available RAM: 5.90 GB
# Fetching clinical drug trials: 24300studies [06:04, 70.63studies/s]2025-06-06 00:05:45,327 - INFO - Available RAM: 5.88 GB
# Fetching clinical drug trials: 24400studies [06:05, 67.51studies/s]2025-06-06 00:05:46,960 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 24500studies [06:07, 61.87studies/s]2025-06-06 00:05:48,886 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 24600studies [06:08, 66.18studies/s]2025-06-06 00:05:50,151 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 24700studies [06:10, 70.01studies/s]2025-06-06 00:05:51,387 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 24800studies [06:11, 71.23studies/s]2025-06-06 00:05:52,733 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 24900studies [06:13, 67.70studies/s]2025-06-06 00:05:54,381 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 25000studies [06:14, 64.76studies/s]2025-06-06 00:05:56,097 - INFO - Available RAM: 5.90 GB
# Fetching clinical drug trials: 25100studies [06:16, 64.09studies/s]2025-06-06 00:05:57,680 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 25200studies [06:18, 60.93studies/s]2025-06-06 00:05:59,510 - INFO - Available RAM: 5.92 GB
# Fetching clinical drug trials: 25300studies [06:20, 58.70studies/s]2025-06-06 00:06:01,375 - INFO - Available RAM: 5.91 GB
# Fetching clinical drug trials: 25400studies [06:22, 55.81studies/s]2025-06-06 00:06:03,357 - INFO - Available RAM: 5.88 GB
# Fetching clinical drug trials: 25500studies [06:24, 54.08studies/s]2025-06-06 00:06:05,356 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 25600studies [06:25, 57.66studies/s]2025-06-06 00:06:06,808 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 25700studies [06:27, 58.89studies/s]2025-06-06 00:06:08,420 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 25800studies [06:28, 59.58studies/s]2025-06-06 00:06:10,069 - INFO - Available RAM: 5.86 GB
# Fetching clinical drug trials: 25900studies [06:30, 59.90studies/s]2025-06-06 00:06:11,701 - INFO - Available RAM: 5.86 GB
# Fetching clinical drug trials: 26000studies [06:31, 69.28studies/s]2025-06-06 00:06:12,633 - INFO - Available RAM: 5.85 GB
# Fetching clinical drug trials: 26100studies [06:32, 77.51studies/s]2025-06-06 00:06:13,549 - INFO - Available RAM: 5.85 GB
# Fetching clinical drug trials: 26200studies [06:33, 71.26studies/s]2025-06-06 00:06:15,231 - INFO - Available RAM: 5.85 GB
# Fetching clinical drug trials: 26300studies [06:35, 76.25studies/s]2025-06-06 00:06:16,333 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 26400studies [06:36, 70.54studies/s]2025-06-06 00:06:17,979 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 26500studies [06:38, 70.32studies/s]2025-06-06 00:06:19,412 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 26600studies [06:39, 70.60studies/s]2025-06-06 00:06:20,829 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 26700studies [06:41, 66.90studies/s]2025-06-06 00:06:22,492 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 26800studies [06:42, 65.11studies/s]2025-06-06 00:06:24,140 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 26900studies [06:44, 64.73studies/s]2025-06-06 00:06:25,690 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 27000studies [06:46, 63.86studies/s]2025-06-06 00:06:27,305 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 27100studies [06:47, 62.47studies/s]2025-06-06 00:06:28,987 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 27200studies [06:49, 63.04studies/s]2025-06-06 00:06:30,544 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 27300studies [06:50, 72.77studies/s]2025-06-06 00:06:31,419 - INFO - Available RAM: 5.85 GB
# Fetching clinical drug trials: 27400studies [06:51, 74.55studies/s]2025-06-06 00:06:32,700 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 27500studies [06:53, 69.51studies/s]2025-06-06 00:06:34,349 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 27600studies [06:54, 72.64studies/s]2025-06-06 00:06:35,581 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 27700studies [06:56, 65.22studies/s]2025-06-06 00:06:37,480 - INFO - Available RAM: 5.84 GB
# Fetching clinical drug trials: 27800studies [06:57, 75.86studies/s]2025-06-06 00:06:38,297 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 27900studies [06:58, 68.16studies/s]2025-06-06 00:06:40,111 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 28000studies [06:59, 78.01studies/s]2025-06-06 00:06:40,961 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 28100studies [07:00, 85.00studies/s]2025-06-06 00:06:41,895 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 28200studies [07:01, 91.00studies/s]2025-06-06 00:06:42,826 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 28300studies [07:02, 96.91studies/s]2025-06-06 00:06:43,689 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 28400studies [07:04, 78.18studies/s]2025-06-06 00:06:45,557 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 28500studies [07:05, 73.26studies/s]2025-06-06 00:06:47,106 - INFO - Available RAM: 5.78 GB
# Fetching clinical drug trials: 28600studies [07:07, 67.31studies/s]2025-06-06 00:06:48,888 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 28700studies [07:09, 59.39studies/s]2025-06-06 00:06:51,019 - INFO - Available RAM: 5.68 GB
# Fetching clinical drug trials: 28800studies [07:11, 61.79studies/s]2025-06-06 00:06:52,485 - INFO - Available RAM: 5.67 GB
# Fetching clinical drug trials: 28900studies [07:13, 59.62studies/s]2025-06-06 00:06:54,300 - INFO - Available RAM: 5.65 GB
# Fetching clinical drug trials: 29000studies [07:14, 57.49studies/s]2025-06-06 00:06:56,184 - INFO - Available RAM: 5.72 GB
# Fetching clinical drug trials: 29100studies [07:16, 58.60studies/s]2025-06-06 00:06:57,830 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 29200studies [07:18, 59.91studies/s]2025-06-06 00:06:59,396 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 29300studies [07:19, 60.86studies/s]2025-06-06 00:07:00,978 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 29400studies [07:21, 60.98studies/s]2025-06-06 00:07:02,613 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 29500studies [07:23, 57.21studies/s]2025-06-06 00:07:04,619 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 29600studies [07:24, 58.74studies/s]2025-06-06 00:07:06,207 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 29700studies [07:26, 56.77studies/s]2025-06-06 00:07:08,106 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 29800studies [07:27, 65.24studies/s]2025-06-06 00:07:09,105 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 29900studies [07:29, 62.74studies/s]2025-06-06 00:07:10,844 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 30000studies [07:31, 59.01studies/s]2025-06-06 00:07:12,771 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 30100studies [07:32, 70.17studies/s]2025-06-06 00:07:13,567 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 30200studies [07:33, 68.86studies/s]2025-06-06 00:07:15,083 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 30300studies [07:35, 63.45studies/s]2025-06-06 00:07:16,948 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 30400studies [07:37, 63.58studies/s]2025-06-06 00:07:18,531 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 30500studies [07:38, 67.53studies/s]2025-06-06 00:07:19,779 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 30600studies [07:40, 65.27studies/s]2025-06-06 00:07:21,431 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 30700studies [07:41, 62.82studies/s]2025-06-06 00:07:23,163 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 30800studies [07:43, 60.13studies/s]2025-06-06 00:07:24,992 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 30900studies [07:45, 59.54studies/s]2025-06-06 00:07:26,724 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 31000studies [07:46, 68.28studies/s]2025-06-06 00:07:27,673 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 31100studies [07:47, 75.76studies/s]2025-06-06 00:07:28,655 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 31200studies [07:49, 70.25studies/s]2025-06-06 00:07:30,321 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 31300studies [07:50, 72.66studies/s]2025-06-06 00:07:31,586 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 31400studies [07:52, 66.75studies/s]2025-06-06 00:07:33,369 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 31500studies [07:53, 64.38studies/s]2025-06-06 00:07:35,051 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 31600studies [07:55, 65.28studies/s]2025-06-06 00:07:36,532 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 31700studies [07:56, 73.68studies/s]2025-06-06 00:07:37,482 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 31800studies [07:57, 81.65studies/s]2025-06-06 00:07:38,398 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 31900studies [07:58, 76.16studies/s]2025-06-06 00:07:39,930 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 32000studies [07:59, 82.12studies/s]2025-06-06 00:07:40,912 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 32100studies [08:01, 75.64studies/s]2025-06-06 00:07:42,495 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 32200studies [08:02, 71.68studies/s]2025-06-06 00:07:44,043 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 32300studies [08:04, 72.40studies/s]2025-06-06 00:07:45,392 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 32400studies [08:05, 79.90studies/s]2025-06-06 00:07:46,341 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 32500studies [08:06, 71.65studies/s]2025-06-06 00:07:48,073 - INFO - Available RAM: 5.77 GB
# Fetching clinical drug trials: 32600studies [08:08, 68.85studies/s]2025-06-06 00:07:49,671 - INFO - Available RAM: 5.78 GB
# Fetching clinical drug trials: 32700studies [08:09, 74.60studies/s]2025-06-06 00:07:50,738 - INFO - Available RAM: 5.78 GB
# Fetching clinical drug trials: 32800studies [08:10, 73.87studies/s]2025-06-06 00:07:52,122 - INFO - Available RAM: 5.76 GB
# Fetching clinical drug trials: 32900studies [08:11, 83.56studies/s]2025-06-06 00:07:52,952 - INFO - Available RAM: 5.77 GB
# Fetching clinical drug trials: 33000studies [08:13, 72.98studies/s]2025-06-06 00:07:54,727 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 33100studies [08:14, 82.92studies/s]2025-06-06 00:07:55,550 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 33200studies [08:15, 84.04studies/s]2025-06-06 00:07:56,716 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 33300studies [08:17, 74.49studies/s]2025-06-06 00:07:58,401 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 33400studies [08:18, 81.72studies/s]2025-06-06 00:07:59,364 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 33500studies [08:19, 71.37studies/s]2025-06-06 00:08:01,179 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 33600studies [08:21, 63.89studies/s]2025-06-06 00:08:03,128 - INFO - Available RAM: 5.78 GB
# Fetching clinical drug trials: 33700studies [08:23, 64.50studies/s]2025-06-06 00:08:04,626 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 33800studies [08:25, 59.75studies/s]2025-06-06 00:08:06,592 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 33900studies [08:26, 68.38studies/s]2025-06-06 00:08:07,557 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 34000studies [08:27, 66.04studies/s]2025-06-06 00:08:09,192 - INFO - Available RAM: 5.83 GB
# Fetching clinical drug trials: 34100studies [08:28, 75.74studies/s]2025-06-06 00:08:10,060 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 34200studies [08:30, 71.82studies/s]2025-06-06 00:08:11,621 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 34300studies [08:31, 69.87studies/s]2025-06-06 00:08:13,146 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 34400studies [08:33, 68.05studies/s]2025-06-06 00:08:14,702 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 34500studies [08:35, 66.69studies/s]2025-06-06 00:08:16,271 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 34600studies [08:36, 73.90studies/s]2025-06-06 00:08:17,283 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 34700studies [08:36, 83.19studies/s]2025-06-06 00:08:18,148 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 34800studies [08:38, 75.40studies/s]2025-06-06 00:08:19,765 - INFO - Available RAM: 5.82 GB
# Fetching clinical drug trials: 34900studies [08:40, 66.77studies/s]2025-06-06 00:08:21,646 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 35000studies [08:41, 70.45studies/s]2025-06-06 00:08:22,883 - INFO - Available RAM: 5.79 GB
# Fetching clinical drug trials: 35100studies [08:43, 67.03studies/s]2025-06-06 00:08:24,560 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 35200studies [08:45, 63.24studies/s]2025-06-06 00:08:26,342 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 35300studies [08:46, 61.96studies/s]2025-06-06 00:08:28,024 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 35400studies [08:48, 63.51studies/s]2025-06-06 00:08:29,506 - INFO - Available RAM: 5.80 GB
# Fetching clinical drug trials: 35500studies [08:49, 67.22studies/s]2025-06-06 00:08:30,791 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 35600studies [08:51, 62.57studies/s]2025-06-06 00:08:32,648 - INFO - Available RAM: 5.81 GB
# Fetching clinical drug trials: 35700studies [08:52, 63.28studies/s]2025-06-06 00:08:34,186 - INFO - Available RAM: 5.71 GB
# Fetching clinical drug trials: 35800studies [08:54, 60.76studies/s]2025-06-06 00:08:35,985 - INFO - Available RAM: 5.71 GB
# Fetching clinical drug trials: 35900studies [08:56, 58.92studies/s]2025-06-06 00:08:37,802 - INFO - Available RAM: 5.71 GB
# Fetching clinical drug trials: 36000studies [08:58, 59.10studies/s]2025-06-06 00:08:39,482 - INFO - Available RAM: 5.70 GB
# Fetching clinical drug trials: 36100studies [08:59, 59.73studies/s]2025-06-06 00:08:41,114 - INFO - Available RAM: 5.70 GB
# Fetching clinical drug trials: 36200studies [09:00, 68.65studies/s]2025-06-06 00:08:42,072 - INFO - Available RAM: 5.71 GB
# Fetching clinical drug trials: 36300studies [09:01, 78.47studies/s]2025-06-06 00:08:42,912 - INFO - Available RAM: 5.71 GB
# Fetching clinical drug trials: 36400studies [09:03, 72.38studies/s]2025-06-06 00:08:44,544 - INFO - Available RAM: 5.70 GB
# Fetching clinical drug trials: 36500studies [09:05, 66.36studies/s]2025-06-06 00:08:46,343 - INFO - Available RAM: 5.70 GB
# Fetching clinical drug trials: 36600studies [09:06, 61.93studies/s]2025-06-06 00:08:48,210 - INFO - Available RAM: 5.70 GB
# Fetching clinical drug trials: 36700studies [09:08, 65.60studies/s]2025-06-06 00:08:49,540 - INFO - Available RAM: 5.71 GB
# Fetching clinical drug trials: 36800studies [09:09, 74.80studies/s]2025-06-06 00:08:50,423 - INFO - Available RAM: 5.71 GB
# Fetching clinical drug trials: 36900studies [09:10, 68.24studies/s]2025-06-06 00:08:52,205 - INFO - Available RAM: 5.70 GB
# Fetching clinical drug trials: 37000studies [09:13, 57.67studies/s]2025-06-06 00:08:54,553 - INFO - Available RAM: 5.71 GB
# ...
# Fetching clinical drug trials: 205900studies [52:16, 66.03studies/s]2025-06-06 00:51:58,171 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 206000studies [52:18, 64.70studies/s]2025-06-06 00:51:59,788 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 206100studies [52:19, 73.53studies/s]2025-06-06 00:52:00,716 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 206200studies [52:21, 69.69studies/s]2025-06-06 00:52:02,324 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 206300studies [52:22, 66.47studies/s]2025-06-06 00:52:03,991 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 206400studies [52:24, 64.61studies/s]2025-06-06 00:52:05,641 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 206500studies [52:25, 72.17studies/s]2025-06-06 00:52:06,649 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 206600studies [52:26, 78.36studies/s]2025-06-06 00:52:07,669 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 206700studies [52:27, 82.81studies/s]2025-06-06 00:52:08,718 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 206800studies [52:28, 86.20studies/s]2025-06-06 00:52:09,766 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 206900studies [52:30, 75.16studies/s]2025-06-06 00:52:11,494 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 207000studies [52:31, 69.95studies/s]2025-06-06 00:52:13,155 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 207100studies [52:33, 70.72studies/s]2025-06-06 00:52:14,533 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 207200studies [52:34, 68.14studies/s]2025-06-06 00:52:16,125 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 207300studies [52:36, 65.73studies/s]2025-06-06 00:52:17,771 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 207400studies [52:37, 71.24studies/s]2025-06-06 00:52:18,903 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 207500studies [52:39, 68.50studies/s]2025-06-06 00:52:20,493 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 207600studies [52:40, 65.73studies/s]2025-06-06 00:52:22,156 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 207700studies [52:42, 59.63studies/s]2025-06-06 00:52:24,198 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 207800studies [52:44, 66.66studies/s]2025-06-06 00:52:25,286 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 207900studies [52:45, 61.72studies/s]2025-06-06 00:52:27,185 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 208000studies [52:47, 61.34studies/s]2025-06-06 00:52:28,839 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 208100studies [52:49, 59.56studies/s]2025-06-06 00:52:30,631 - INFO - Available RAM: 5.35 GB
# Fetching clinical drug trials: 208200studies [52:50, 60.57studies/s]2025-06-06 00:52:32,216 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 208300studies [52:52, 66.24studies/s]2025-06-06 00:52:33,396 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 208400studies [52:53, 66.02studies/s]2025-06-06 00:52:34,923 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 208500studies [52:55, 62.03studies/s]2025-06-06 00:52:36,762 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 208600studies [52:57, 59.45studies/s]2025-06-06 00:52:38,607 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 208700studies [52:59, 55.80studies/s]2025-06-06 00:52:40,658 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 208800studies [53:01, 55.59studies/s]2025-06-06 00:52:42,471 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 208900studies [53:02, 63.46studies/s]2025-06-06 00:52:43,527 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 209000studies [53:04, 59.74studies/s]2025-06-06 00:52:45,431 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 209100studies [53:05, 62.35studies/s]2025-06-06 00:52:46,870 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 209200studies [53:07, 60.05studies/s]2025-06-06 00:52:48,678 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 209300studies [53:08, 61.34studies/s]2025-06-06 00:52:50,228 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 209400studies [53:10, 59.65studies/s]2025-06-06 00:52:52,013 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 209500studies [53:12, 59.33studies/s]2025-06-06 00:52:53,718 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 209600studies [53:13, 67.10studies/s]2025-06-06 00:52:54,754 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 209700studies [53:14, 68.16studies/s]2025-06-06 00:52:56,170 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 209800studies [53:16, 64.71studies/s]2025-06-06 00:52:57,894 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 209900studies [53:18, 62.65studies/s]2025-06-06 00:52:59,609 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 210000studies [53:20, 59.20studies/s]2025-06-06 00:53:01,515 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 210100studies [53:22, 57.91studies/s]2025-06-06 00:53:03,330 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 210200studies [53:23, 59.15studies/s]2025-06-06 00:53:04,937 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 210300studies [53:25, 56.21studies/s]2025-06-06 00:53:06,921 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 210400studies [53:27, 56.61studies/s]2025-06-06 00:53:08,659 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 210500studies [53:28, 61.91studies/s]2025-06-06 00:53:09,920 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 210600studies [53:30, 59.59studies/s]2025-06-06 00:53:11,746 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 210700studies [53:31, 63.19studies/s]2025-06-06 00:53:13,105 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 210800studies [53:32, 69.92studies/s]2025-06-06 00:53:14,180 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 210900studies [53:33, 78.24studies/s]2025-06-06 00:53:15,102 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 211000studies [53:34, 82.99studies/s]2025-06-06 00:53:16,138 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 211100studies [53:36, 83.92studies/s]2025-06-06 00:53:17,298 - INFO - Available RAM: 5.39 GB
# Fetching clinical drug trials: 211200studies [53:37, 76.71studies/s]2025-06-06 00:53:18,863 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 211300studies [53:39, 64.52studies/s]2025-06-06 00:53:20,989 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 211400studies [53:41, 62.50studies/s]2025-06-06 00:53:22,703 - INFO - Available RAM: 5.38 GB
# Fetching clinical drug trials: 211500studies [53:43, 62.73studies/s]2025-06-06 00:53:24,285 - INFO - Available RAM: 5.37 GB
# Fetching clinical drug trials: 211600studies [53:44, 62.20studies/s]2025-06-06 00:53:25,924 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 211700studies [53:45, 69.60studies/s]2025-06-06 00:53:26,963 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 211800studies [53:46, 75.78studies/s]2025-06-06 00:53:28,010 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 211900studies [53:48, 69.89studies/s]2025-06-06 00:53:29,700 - INFO - Available RAM: 5.33 GB
# Fetching clinical drug trials: 212000studies [53:50, 66.71studies/s]2025-06-06 00:53:31,357 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 212100studies [53:52, 61.26studies/s]2025-06-06 00:53:33,301 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 212200studies [53:53, 66.86studies/s]2025-06-06 00:53:34,477 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 212300studies [53:55, 62.65studies/s]2025-06-06 00:53:36,308 - INFO - Available RAM: 5.30 GB
# Fetching clinical drug trials: 212400studies [53:57, 56.22studies/s]2025-06-06 00:53:38,513 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 212500studies [53:58, 63.41studies/s]2025-06-06 00:53:39,619 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 212600studies [53:59, 63.27studies/s]2025-06-06 00:53:41,208 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 212700studies [54:00, 70.32studies/s]2025-06-06 00:53:42,262 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 212800studies [54:02, 69.43studies/s]2025-06-06 00:53:43,742 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 212900studies [54:03, 75.67studies/s]2025-06-06 00:53:44,788 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 213000studies [54:05, 64.22studies/s]2025-06-06 00:53:46,894 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 213100studies [54:07, 56.28studies/s]2025-06-06 00:53:49,185 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 213200studies [54:09, 60.93studies/s]2025-06-06 00:53:50,507 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 213300studies [54:10, 66.35studies/s]2025-06-06 00:53:51,702 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 213400studies [54:11, 74.57studies/s]2025-06-06 00:53:52,655 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 213500studies [54:12, 78.14studies/s]2025-06-06 00:53:53,793 - INFO - Available RAM: 5.31 GB
# Fetching clinical drug trials: 213600studies [54:14, 72.07studies/s]2025-06-06 00:53:55,432 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 213700studies [54:15, 79.57studies/s]2025-06-06 00:53:56,383 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 213800studies [54:16, 73.79studies/s]2025-06-06 00:53:57,968 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 213900studies [54:18, 73.00studies/s]2025-06-06 00:53:59,374 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 214000studies [54:20, 58.20studies/s]2025-06-06 00:54:01,905 - INFO - Available RAM: 5.21 GB
# Fetching clinical drug trials: 214100studies [54:21, 64.00studies/s]2025-06-06 00:54:03,104 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 214200studies [54:23, 66.64studies/s]2025-06-06 00:54:04,460 - INFO - Available RAM: 5.21 GB
# Fetching clinical drug trials: 214300studies [54:24, 72.11studies/s]2025-06-06 00:54:05,580 - INFO - Available RAM: 5.24 GB
# Fetching clinical drug trials: 214400studies [54:26, 63.07studies/s]2025-06-06 00:54:07,630 - INFO - Available RAM: 5.28 GB
# Fetching clinical drug trials: 214500studies [54:28, 59.91studies/s]2025-06-06 00:54:09,495 - INFO - Available RAM: 5.22 GB
# Fetching clinical drug trials: 214600studies [54:29, 59.30studies/s]2025-06-06 00:54:11,221 - INFO - Available RAM: 5.34 GB
# Fetching clinical drug trials: 214700studies [54:31, 65.07studies/s]2025-06-06 00:54:12,408 - INFO - Available RAM: 5.34 GB
# Fetching clinical drug trials: 214800studies [54:32, 69.27studies/s]2025-06-06 00:54:13,634 - INFO - Available RAM: 5.35 GB
# Fetching clinical drug trials: 214900studies [54:33, 72.54studies/s]2025-06-06 00:54:14,861 - INFO - Available RAM: 5.36 GB
# Fetching clinical drug trials: 215000studies [54:35, 65.03studies/s]2025-06-06 00:54:16,770 - INFO - Available RAM: 5.35 GB
# Fetching clinical drug trials: 215100studies [54:37, 64.24studies/s]2025-06-06 00:54:18,371 - INFO - Available RAM: 5.35 GB
# Fetching clinical drug trials: 215200studies [54:38, 62.05studies/s]2025-06-06 00:54:20,111 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 215300studies [54:40, 60.88studies/s]2025-06-06 00:54:21,825 - INFO - Available RAM: 5.32 GB
# Fetching clinical drug trials: 215400studies [54:42, 60.45studies/s]2025-06-06 00:54:23,506 - INFO - Available RAM: 5.21 GB
# Fetching clinical drug trials: 215500studies [54:43, 65.94studies/s]2025-06-06 00:54:24,703 - INFO - Available RAM: 5.19 GB
# Fetching clinical drug trials: 215600studies [54:45, 64.56studies/s]2025-06-06 00:54:26,328 - INFO - Available RAM: 5.20 GB
# Fetching clinical drug trials: 215700studies [54:46, 62.66studies/s]2025-06-06 00:54:28,032 - INFO - Available RAM: 5.20 GB
# Fetching clinical drug trials: 215800studies [54:48, 60.72studies/s]2025-06-06 00:54:29,798 - INFO - Available RAM: 5.20 GB
# Fetching clinical drug trials: 215900studies [54:50, 58.56studies/s]2025-06-06 00:54:31,648 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 216000studies [54:52, 57.35studies/s]2025-06-06 00:54:33,476 - INFO - Available RAM: 5.21 GB
# Fetching clinical drug trials: 216100studies [54:53, 58.93studies/s]2025-06-06 00:54:35,063 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 216200studies [54:55, 58.99studies/s]2025-06-06 00:54:36,754 - INFO - Available RAM: 5.24 GB
# Fetching clinical drug trials: 216300studies [54:57, 55.59studies/s]2025-06-06 00:54:38,796 - INFO - Available RAM: 5.21 GB
# Fetching clinical drug trials: 216400studies [54:58, 61.94studies/s]2025-06-06 00:54:39,980 - INFO - Available RAM: 5.21 GB
# Fetching clinical drug trials: 216500studies [55:00, 64.22studies/s]2025-06-06 00:54:41,405 - INFO - Available RAM: 5.22 GB
# Fetching clinical drug trials: 216600studies [55:01, 69.75studies/s]2025-06-06 00:54:42,549 - INFO - Available RAM: 5.24 GB
# Fetching clinical drug trials: 216700studies [55:02, 72.29studies/s]2025-06-06 00:54:43,814 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 216800studies [55:04, 68.65studies/s]2025-06-06 00:54:45,441 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 216900studies [55:05, 76.64studies/s]2025-06-06 00:54:46,392 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 217000studies [55:06, 72.14studies/s]2025-06-06 00:54:47,967 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 217100studies [55:08, 65.50studies/s]2025-06-06 00:54:49,822 - INFO - Available RAM: 5.22 GB
# Fetching clinical drug trials: 217200studies [55:10, 64.16studies/s]2025-06-06 00:54:51,455 - INFO - Available RAM: 5.24 GB
# Fetching clinical drug trials: 217300studies [55:11, 64.10studies/s]2025-06-06 00:54:53,018 - INFO - Available RAM: 5.24 GB
# Fetching clinical drug trials: 217400studies [55:13, 61.73studies/s]2025-06-06 00:54:54,779 - INFO - Available RAM: 5.24 GB
# Fetching clinical drug trials: 217500studies [55:15, 62.40studies/s]2025-06-06 00:54:56,342 - INFO - Available RAM: 5.25 GB
# Fetching clinical drug trials: 217600studies [55:16, 61.38studies/s]2025-06-06 00:54:58,032 - INFO - Available RAM: 5.25 GB
# Fetching clinical drug trials: 217700studies [55:18, 61.08studies/s]2025-06-06 00:54:59,688 - INFO - Available RAM: 5.25 GB
# Fetching clinical drug trials: 217800studies [55:20, 61.40studies/s]2025-06-06 00:55:01,296 - INFO - Available RAM: 5.25 GB
# Fetching clinical drug trials: 217900studies [55:20, 70.17studies/s]2025-06-06 00:55:02,249 - INFO - Available RAM: 5.26 GB
# Fetching clinical drug trials: 218000studies [55:22, 67.35studies/s]2025-06-06 00:55:03,870 - INFO - Available RAM: 5.25 GB
# Fetching clinical drug trials: 218100studies [55:23, 71.79studies/s]2025-06-06 00:55:05,050 - INFO - Available RAM: 5.26 GB
# Fetching clinical drug trials: 218200studies [55:25, 66.19studies/s]2025-06-06 00:55:06,836 - INFO - Available RAM: 5.23 GB
# Fetching clinical drug trials: 218300studies [55:27, 64.45studies/s]2025-06-06 00:55:08,483 - INFO - Available RAM: 5.25 GB
# Fetching clinical drug trials: 218400studies [55:29, 61.53studies/s]2025-06-06 00:55:10,280 - INFO - Available RAM: 5.24 GB
# Fetching clinical drug trials: 218466studies [55:30, 65.60studies/s]
# 2025-06-06 00:55:11,772 - INFO - Fetched 218466 clinical drug trials and saved to d:\IIT Patna\Leveraging-ai-clinical-trials\clinical_drug_trials_all_records.json.
# 2025-06-06 00:55:11,777 - INFO - Data fetching complete. You can now access the data in the JSON file for your research.

# %%
# Install required packages (if not already installed)
# !pip install pandas tqdm psutil ijson

import pandas as pd
from tqdm import tqdm
import os
import logging
import psutil
import sys
import json
import gc
import ijson  # For streaming JSON parsing

# Set up logging (consistent with the previous program)
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# File containing the API data (JSON format)
DATA_FILE = "clinical_drug_trials_all_records.json"

# Display the JSON file location
json_path = os.path.abspath(DATA_FILE)
logging.info(f"JSON file location: {json_path}")

# Function to check available RAM
def check_available_ram():
    memory = psutil.virtual_memory()
    available_ram = memory.available / (1024 ** 3)  # Convert to GB
    logging.info(f"Available RAM: {available_ram:.2f} GB")
    return available_ram

# Step 1: Extract and Print the Header of the JSON File
def print_json_header(num_records_to_sample=1):
    if not os.path.exists(DATA_FILE):
        logging.error(f"JSON file not found at: {json_path}")
        return

    try:
        check_available_ram()
        # Stream the JSON file to load a small sample of records
        records = []
        file_size = os.path.getsize(DATA_FILE) // (1024 ** 2)  # File size in MB
        logging.info("Streaming JSON data to load sample records for header extraction...")
        with open(DATA_FILE, 'r', encoding='utf-8') as f:
            # Use ijson to parse the JSON array incrementally
            parser = ijson.items(f, 'item')
            with tqdm(total=num_records_to_sample, desc="Loading sample records", unit="records") as pbar:
                for i, record in enumerate(parser):
                    if i >= num_records_to_sample:
                        break
                    records.append(record)
                    pbar.update(1)

        if not records:
            logging.info("No records found in the JSON file.")
            return

        # Flatten the JSON structure into a DataFrame to determine the header
        logging.info("Flattening JSON data to extract header...")
        df = pd.json_normalize(records)
        header = df.columns.tolist()
        logging.info(f"Total number of columns in the header: {len(header)}")

        # Print the header in a readable format
        logging.info(f"\nHeader (Column Names) of the JSON File:\n{'-'*50}")
        for i, col in enumerate(header, 1):
            print(f"{i}. {col}")
        print('-'*50)

        # Clean up memory
        del df
        del records
        gc.collect()
        check_available_ram()

    except Exception as e:
        logging.error(f"Error extracting header from JSON file: {e}")

# Main Workflow
def main():
    # Extract and print the header
    print_json_header(num_records_to_sample=1)
    logging.info("Header extraction complete. You can now use the JSON file for further analytics.")

if __name__ == "__main__":
    main()
